# %%
# !python run.py
# Out:
# ...
# 100%|##########| 1848/1848 [02:53<00:00, 10.68it/s]
#
#   0%|          | 0/1700 [00:00<?, ?it/s]
# 1445850it [00:00, 52313921.76it/s]
#
# ...
#   1%|          | 18/1848 [00:07<02:43, 11.17it/s]
# ...
# ...
# 100%|##########| 1848/1848 [01:14<00:00, 24.77it/s]
#
#   0%|          | 0/1700 [00:00<?, ?it/s]
# 1445850it [00:00, 52154204.52it/s]
#
#   0%|          | 0/2416 [00:00<?, ?it/s]
# 2919736it [00:00, 90836173.36it/s]
# Using device:  cpu
# ...
# INITIALIZING
# ...
# Loading data...
# took 0.95 seconds
# Building parser...
# took 0.52 seconds
# Loading pretrained embeddings...
# took 1.48 seconds
# Vectorizing data...
# took 1.00 seconds
# Preprocessing training data...
# took 41.79 seconds
# took 0.03 seconds
#
# ...
# TRAINING
# ...
# Epoch 1 out of 10
# Average Train Loss: 0.1825904809986745
# Evaluating on dev set
# - dev UAS: 83.76
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# Average Train Loss: 0.11447002880630039
# Evaluating on dev set
# - dev UAS: 86.41
# New best dev UAS! Saving model.
#
# ...
